# %%
import sys
import numpy as np
import pandas as pd

from settings import classifiers_settings_test
from fairness_experiments import Experiment

# %%
german = pd.read_csv('dataset_test.txt', sep=',', index_col=0)
german
# Out:
#           status  duration (month)  credit amount   savings  employment since  \
# sex
# Male   -1.268991         -1.236478      -0.745131 -1.231393          1.338078
# Female  0.995043          2.248194       0.949817 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.416562 -0.196609          0.510060
# Male   -1.268991          1.750384       1.634247 -0.196609          0.510060
# Male   -1.268991          0.256953       0.566664 -0.196609         -0.317959
# ...          ...               ...            ...       ...               ...
# Female -0.136974         -0.738668      -0.544162 -0.196609          0.510060
# Male   -1.268991          0.754763       0.207612 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.874503 -0.196609          1.338078
# Male   -1.268991          1.999289      -0.505528 -0.196609         -0.317959
# Male    0.995043          1.999289       0.462457  0.838175         -1.973997
#
#         installment rate  residence since       age   credits       job  ...  \
# sex                                                                      ...
# Male            0.918477         1.046987  2.766456  1.027079  0.146949  ...
# Female         -0.870183        -0.765977 -1.191404 -0.704926  0.146949  ...
# Male           -0.870183         0.140505  1.183312 -0.704926 -1.383771  ...
# Male           -0.870183         1.046987  0.831502 -0.704926  0.146949  ...
# Male            0.024147         1.046987  1.535122  1.027079  0.146949  ...
# ...                  ...              ...       ...       ...       ...  ...
# Female          0.024147         1.046987 -0.399832 -0.704926 -1.383771  ...
# Male            0.918477         1.046987  0.391740 -0.704926  1.677670  ...
# Male            0.918477         1.046987  0.215835 -0.704926  0.146949  ...
# Male            0.918477         1.046987 -1.103451 -0.704926  0.146949  ...
# Male            0.024147         1.046987 -0.751642 -0.704926  0.146949  ...
#
#         property_A122  property_A123  property_A124  installment plans_A142  \
# sex
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# ...               ...            ...            ...                     ...
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
#
#         installment plans_A143  housing_A152  housing_A153  phone_A192  \
# sex
# Male                  0.478018      0.634448     -0.347960    1.214598
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# ...                        ...           ...           ...         ...
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
#
#         foreign worker_A202  class
# sex
# Male              -0.196014      1
# Female            -0.196014      0
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# ...                     ...    ...
# Female            -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# Male              -0.196014      1
#
# [1000 rows x 37 columns]

# %%
X = german.loc[:, german.columns != 'class']
y = np.array(german.loc[:, german.columns == 'class']).ravel()

# %%
exp_teste = Experiment(classifiers_settings_test, dataset_name='German', preprocessing_name='sem pré-processamento', 
                 privileged_group='Male')
exp_teste.execute(X, y)
exp_teste.report
# Out:
# (German - sem pré-processamento) - Classificador MLP (6/6) - Progresso Geral (17/17)
#    dataset          preprocessing       clf_type  \
# 0   German  sem pré-processamento  Random Forest
# 1   German  sem pré-processamento  Random Forest
# 2   German  sem pré-processamento  Random Forest
# 3   German  sem pré-processamento  Random Forest
# 4   German  sem pré-processamento  Random Forest
# 5   German  sem pré-processamento    Naive Bayes
# 6   German  sem pré-processamento  Decision Tree
# 7   German  sem pré-processamento  Decision Tree
# 8   German  sem pré-processamento  Decision Tree
# 9   German  sem pré-processamento  Decision Tree
# 10  German  sem pré-processamento        XGBoost
# 11  German  sem pré-processamento            MLP
# 12  German  sem pré-processamento            MLP
# 13  German  sem pré-processamento            MLP
# 14  German  sem pré-processamento            MLP
# 15  German  sem pré-processamento            MLP
# 16  German  sem pré-processamento            MLP
#
#                                                params  accuracy  dif_accuracy  \
# 0                               {'n_estimators': 120}     0.767      0.061162
# 1                               {'n_estimators': 140}     0.761      0.065032
# 2                               {'n_estimators': 160}     0.763      0.062292
# 3                               {'n_estimators': 180}     0.761      0.044958
# 4                               {'n_estimators': 200}     0.765      0.069264
# 5                                                  {}     0.630      0.073140
# 6           {'criterion': 'gini', 'splitter': 'best'}     0.701      0.094385
# 7         {'criterion': 'gini', 'splitter': 'random'}     0.680      0.099700
# 8        {'criterion': 'entropy', 'splitter': 'best'}     0.696      0.107346
# 9      {'criterion': 'entropy', 'splitter': 'random'}     0.684      0.076336
# 10                   {'objective': 'binary:logistic'}     0.757      0.064954
# 11        {'hidden_layer_sizes': 5, 'max_iter': 5000}     0.714      0.051552
# 12        {'hidden_layer_sizes': 8, 'max_iter': 5000}     0.702      0.061839
# 13       {'hidden_layer_sizes': 15, 'max_iter': 5000}     0.702      0.070551
# 14   {'hidden_layer_sizes': (5, 5), 'max_iter': 5000}     0.701      0.080951
# 15  {'hidden_layer_sizes': (10, 10), 'max_iter': 5...     0.672      0.092071
# 16  {'hidden_layer_sizes': (5, 5, 5), 'max_iter': ...     0.689      0.084545
#
#     balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  precision  \
# 0            0.660238               0.096682  0.927143    0.045237   0.781563
# 1            0.651190               0.071734  0.925714    0.040292   0.776474
# 2            0.654524               0.078574  0.925714    0.048262   0.778949
# 3            0.653095               0.062957  0.922857    0.029183   0.778543
# 4            0.661667               0.079645  0.920000    0.039689   0.783117
# 5            0.605238               0.085483  0.667143    0.090561   0.784559
# 6            0.647381               0.077293  0.781429    0.107498   0.790991
# 7            0.622857               0.124036  0.765714    0.125266   0.775317
# 8            0.641905               0.121558  0.777143    0.114832   0.787330
# 9            0.624762               0.118754  0.772857    0.135768   0.775556
# 10           0.687381               0.064990  0.861429    0.073905   0.805340
# 11           0.640476               0.047693  0.824286    0.064907   0.779886
# 12           0.632857               0.093027  0.805714    0.067405   0.777220
# 13           0.649048               0.086454  0.781429    0.064280   0.791105
# 14           0.613095               0.082841  0.832857    0.082514   0.763187
# 15           0.607619               0.134246  0.768571    0.088430   0.764065
# 16           0.607381               0.088350  0.811429    0.100951   0.760552
#
#     dif_precision       fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0        0.057985  0.606667  0.171130           0.831            0.085442
# 1        0.069508  0.623333  0.151493           0.835            0.095288
# 2        0.061262  0.616667  0.149439           0.833            0.093469
# 3        0.057488  0.616667  0.141482           0.831            0.088993
# 4        0.070136  0.596667  0.135028           0.823            0.073747
# 5        0.109373  0.456667  0.175588           0.604            0.089506
# 6        0.073700  0.486667  0.102039           0.693            0.093297
# 7        0.086080  0.520000  0.195937           0.692            0.109048
# 8        0.136550  0.493333  0.206381           0.692            0.086767
# 9        0.073081  0.523333  0.237941           0.698            0.133895
# 10       0.063983  0.486667  0.141109           0.749            0.099802
# 11       0.064681  0.543333  0.086295           0.740            0.069390
# 12       0.054105  0.540000  0.161151           0.726            0.096227
# 13       0.072590  0.483333  0.186811           0.692            0.094780
# 14       0.079808  0.606667  0.117011           0.765            0.067996
# 15       0.082352  0.553333  0.225737           0.704            0.123110
# 16       0.093782  0.596667  0.176715           0.747            0.109441
#
#     dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                 0.085442       0.045237      0.086585
# 1                 0.095288       0.040292      0.092863
# 2                 0.093469       0.048262      0.078190
# 3                 0.088993       0.029183      0.083447
# 4                 0.073747       0.039689      0.070802
# 5                 0.089506       0.090561      0.095734
# 6                 0.093297       0.107498      0.069232
# 7                 0.109048       0.125266      0.105089
# 8                 0.086767       0.114832      0.103137
# 9                 0.133895       0.135768      0.142386
# 10                0.099802       0.073905      0.090649
# 11                0.069390       0.064907      0.055502
# 12                0.096227       0.067405      0.096052
# 13                0.094780       0.064280      0.106344
# 14                0.067996       0.082514      0.058095
# 15                0.123110       0.088430      0.128001
# 16                0.109441       0.100951      0.109496
#
#     disparate_impacto_ratio
# 0                  0.908721
# 1                  0.909864
# 2                  0.922804
# 3                  0.921169
# 4                  0.919194
# 5                  0.967596
# 6                  0.943909
# 7                  0.923053
# 8                  0.998164
# 9                  0.926852
# 10                 0.909909
# 11                 0.968680
# 12                 0.880462
# 13                 0.869517
# 14                 0.929532
# 15                 0.863404
# 16                 0.883029

# %%
exp_teste.export_report(relative_path='resultados_teste/')
