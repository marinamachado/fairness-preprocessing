# %%
import sys
import numpy as np
import pandas as pd

from settings import classifiers_settings_test, classifiers_settings_test_weights
from fairness_experiments import Experiment

# %%
german = pd.read_csv('dataset_test.txt', sep=',', index_col=0)
german
# Out:
#           status  duration (month)  credit amount   savings  employment since  \
# sex
# Male   -1.268991         -1.236478      -0.745131 -1.231393          1.338078
# Female  0.995043          2.248194       0.949817 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.416562 -0.196609          0.510060
# Male   -1.268991          1.750384       1.634247 -0.196609          0.510060
# Male   -1.268991          0.256953       0.566664 -0.196609         -0.317959
# ...          ...               ...            ...       ...               ...
# Female -0.136974         -0.738668      -0.544162 -0.196609          0.510060
# Male   -1.268991          0.754763       0.207612 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.874503 -0.196609          1.338078
# Male   -1.268991          1.999289      -0.505528 -0.196609         -0.317959
# Male    0.995043          1.999289       0.462457  0.838175         -1.973997
#
#         installment rate  residence since       age   credits       job  ...  \
# sex                                                                      ...
# Male            0.918477         1.046987  2.766456  1.027079  0.146949  ...
# Female         -0.870183        -0.765977 -1.191404 -0.704926  0.146949  ...
# Male           -0.870183         0.140505  1.183312 -0.704926 -1.383771  ...
# Male           -0.870183         1.046987  0.831502 -0.704926  0.146949  ...
# Male            0.024147         1.046987  1.535122  1.027079  0.146949  ...
# ...                  ...              ...       ...       ...       ...  ...
# Female          0.024147         1.046987 -0.399832 -0.704926 -1.383771  ...
# Male            0.918477         1.046987  0.391740 -0.704926  1.677670  ...
# Male            0.918477         1.046987  0.215835 -0.704926  0.146949  ...
# Male            0.918477         1.046987 -1.103451 -0.704926  0.146949  ...
# Male            0.024147         1.046987 -0.751642 -0.704926  0.146949  ...
#
#         property_A122  property_A123  property_A124  installment plans_A142  \
# sex
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# ...               ...            ...            ...                     ...
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
#
#         installment plans_A143  housing_A152  housing_A153  phone_A192  \
# sex
# Male                  0.478018      0.634448     -0.347960    1.214598
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# ...                        ...           ...           ...         ...
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
#
#         foreign worker_A202  class
# sex
# Male              -0.196014      1
# Female            -0.196014      0
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# ...                     ...    ...
# Female            -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# Male              -0.196014      1
#
# [1000 rows x 37 columns]

# %%
X = german.loc[:, german.columns != 'class']
y = np.array(german.loc[:, german.columns == 'class']).ravel()

# %%
X
# Out:
#           status  duration (month)  credit amount   savings  employment since  \
# sex
# Male   -1.268991         -1.236478      -0.745131 -1.231393          1.338078
# Female  0.995043          2.248194       0.949817 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.416562 -0.196609          0.510060
# Male   -1.268991          1.750384       1.634247 -0.196609          0.510060
# Male   -1.268991          0.256953       0.566664 -0.196609         -0.317959
# ...          ...               ...            ...       ...               ...
# Female -0.136974         -0.738668      -0.544162 -0.196609          0.510060
# Male   -1.268991          0.754763       0.207612 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.874503 -0.196609          1.338078
# Male   -1.268991          1.999289      -0.505528 -0.196609         -0.317959
# Male    0.995043          1.999289       0.462457  0.838175         -1.973997
#
#         installment rate  residence since       age   credits       job  ...  \
# sex                                                                      ...
# Male            0.918477         1.046987  2.766456  1.027079  0.146949  ...
# Female         -0.870183        -0.765977 -1.191404 -0.704926  0.146949  ...
# Male           -0.870183         0.140505  1.183312 -0.704926 -1.383771  ...
# Male           -0.870183         1.046987  0.831502 -0.704926  0.146949  ...
# Male            0.024147         1.046987  1.535122  1.027079  0.146949  ...
# ...                  ...              ...       ...       ...       ...  ...
# Female          0.024147         1.046987 -0.399832 -0.704926 -1.383771  ...
# Male            0.918477         1.046987  0.391740 -0.704926  1.677670  ...
# Male            0.918477         1.046987  0.215835 -0.704926  0.146949  ...
# Male            0.918477         1.046987 -1.103451 -0.704926  0.146949  ...
# Male            0.024147         1.046987 -0.751642 -0.704926  0.146949  ...
#
#         other debtors_A103  property_A122  property_A123  property_A124  \
# sex
# Male             -0.234206      -0.549621      -0.704987      -0.426653
# Female           -0.234206      -0.549621      -0.704987      -0.426653
# Male             -0.234206      -0.549621      -0.704987      -0.426653
# Male              4.269750       1.819435      -0.704987      -0.426653
# Male             -0.234206      -0.549621      -0.704987       2.343823
# ...                    ...            ...            ...            ...
# Female           -0.234206      -0.549621      -0.704987      -0.426653
# Male             -0.234206       1.819435      -0.704987      -0.426653
# Male             -0.234206      -0.549621       1.418467      -0.426653
# Male             -0.234206      -0.549621      -0.704987       2.343823
# Male             -0.234206      -0.549621       1.418467      -0.426653
#
#         installment plans_A142  installment plans_A143  housing_A152  \
# sex
# Male                 -0.222076                0.478018      0.634448
# Female               -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018     -1.576173
# Male                 -0.222076                0.478018     -1.576173
# ...                        ...                     ...           ...
# Female               -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018     -1.576173
# Male                 -0.222076                0.478018      0.634448
#
#         housing_A153  phone_A192  foreign worker_A202
# sex
# Male       -0.347960    1.214598            -0.196014
# Female     -0.347960   -0.823318            -0.196014
# Male       -0.347960   -0.823318            -0.196014
# Male        2.873893   -0.823318            -0.196014
# Male        2.873893   -0.823318            -0.196014
# ...              ...         ...                  ...
# Female     -0.347960   -0.823318            -0.196014
# Male       -0.347960    1.214598            -0.196014
# Male       -0.347960   -0.823318            -0.196014
# Male        2.873893    1.214598            -0.196014
# Male       -0.347960   -0.823318            -0.196014
#
# [1000 rows x 36 columns]

# %%
exp_teste = Experiment(classifiers_settings_test, dataset_name='German', preprocessing_name='sem pré-processamento', 
                 privileged_group='Male')
exp_teste.execute(X, y)
exp_teste.report
# Out:
# (German - sem pré-processamento) - Classificador Decision Tree (4/4) - Progresso Geral (10/10)
#   dataset          preprocessing       clf_type  \
# 0  German  sem pré-processamento  Random Forest
# 1  German  sem pré-processamento  Random Forest
# 2  German  sem pré-processamento  Random Forest
# 3  German  sem pré-processamento  Random Forest
# 4  German  sem pré-processamento  Random Forest
# 5  German  sem pré-processamento    Naive Bayes
# 6  German  sem pré-processamento  Decision Tree
# 7  German  sem pré-processamento  Decision Tree
# 8  German  sem pré-processamento  Decision Tree
# 9  German  sem pré-processamento  Decision Tree
#
#                                            params  accuracy  dif_accuracy  \
# 0                           {'n_estimators': 120}     0.762      0.062203
# 1                           {'n_estimators': 140}     0.755      0.065602
# 2                           {'n_estimators': 160}     0.759      0.071707
# 3                           {'n_estimators': 180}     0.759      0.059206
# 4                           {'n_estimators': 200}     0.763      0.055723
# 5                                              {}     0.630      0.073140
# 6       {'criterion': 'gini', 'splitter': 'best'}     0.686      0.120151
# 7     {'criterion': 'gini', 'splitter': 'random'}     0.674      0.076946
# 8    {'criterion': 'entropy', 'splitter': 'best'}     0.683      0.101613
# 9  {'criterion': 'entropy', 'splitter': 'random'}     0.678      0.095071
#
#    balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  precision  \
# 0           0.658571               0.072735  0.917143    0.038865   0.782415
# 1           0.651667               0.060152  0.910000    0.052382   0.778819
# 2           0.648810               0.077155  0.924286    0.046430   0.775727
# 3           0.653571               0.086072  0.917143    0.034474   0.779337
# 4           0.656429               0.059853  0.922857    0.041145   0.779866
# 5           0.605238               0.085483  0.667143    0.090561   0.784559
# 6           0.630952               0.107889  0.768571    0.132732   0.780912
# 7           0.619524               0.098505  0.755714    0.097189   0.774127
# 8           0.626905               0.111872  0.767143    0.107752   0.779514
# 9           0.613810               0.112792  0.774286    0.121229   0.768100
#
#    dif_precision       fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0       0.064964  0.600000  0.155884           0.822            0.087005
# 1       0.063253  0.606667  0.117680           0.819            0.095309
# 2       0.072129  0.626667  0.152971           0.835            0.089114
# 3       0.061727  0.610000  0.153708           0.825            0.081207
# 4       0.061824  0.610000  0.130622           0.829            0.088902
# 5       0.109373  0.456667  0.175588           0.604            0.089506
# 6       0.089899  0.506667  0.137390           0.690            0.092870
# 7       0.098955  0.516667  0.174287           0.684            0.103285
# 8       0.121489  0.513333  0.172621           0.691            0.085994
# 9       0.075805  0.546667  0.178136           0.706            0.123586
#
#    dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                0.087005       0.038865      0.085149
# 1                0.095309       0.052382      0.079039
# 2                0.089114       0.046430      0.089380
# 3                0.081207       0.034474      0.071967
# 4                0.088902       0.041145      0.076111
# 5                0.089506       0.090561      0.095734
# 6                0.092870       0.132732      0.077004
# 7                0.103285       0.097189      0.096256
# 8                0.085994       0.107752      0.088984
# 9                0.123586       0.121229      0.113109
#
#    disparate_impacto_ratio
# 0                 0.904364
# 1                 0.908008
# 2                 0.942567
# 3                 0.934664
# 4                 0.934112
# 5                 0.967596
# 6                 0.938896
# 7                 0.977326
# 8                 0.974461
# 9                 0.842763

# %%
exp_teste.export_report(relative_path='resultados_teste/')

# %%
# faz o teste com pesos
weights = [2]*len(y)

# %%
exp_teste = Experiment(classifiers_settings_test_weights, dataset_name='German', preprocessing_name='sem pré-processamento', 
                 privileged_group='Male')
exp_teste.execute(X, y, weights)
exp_teste.report
# Out:
# (German - sem pré-processamento) - Classificador Decision Tree (4/4) - Progresso Geral (10/10)
#   dataset          preprocessing       clf_type  \
# 0  German  sem pré-processamento  Random Forest
# 1  German  sem pré-processamento  Random Forest
# 2  German  sem pré-processamento  Random Forest
# 3  German  sem pré-processamento  Random Forest
# 4  German  sem pré-processamento  Random Forest
# 5  German  sem pré-processamento    Naive Bayes
# 6  German  sem pré-processamento  Decision Tree
# 7  German  sem pré-processamento  Decision Tree
# 8  German  sem pré-processamento  Decision Tree
# 9  German  sem pré-processamento  Decision Tree
#
#                                            params  accuracy  dif_accuracy  \
# 0                           {'n_estimators': 120}     0.755      0.068349
# 1                           {'n_estimators': 140}     0.761      0.041527
# 2                           {'n_estimators': 160}     0.763      0.070395
# 3                           {'n_estimators': 180}     0.750      0.036748
# 4                           {'n_estimators': 200}     0.756      0.060533
# 5                                              {}     0.630      0.073140
# 6       {'criterion': 'gini', 'splitter': 'best'}     0.696      0.104491
# 7     {'criterion': 'gini', 'splitter': 'random'}     0.675      0.099123
# 8    {'criterion': 'entropy', 'splitter': 'best'}     0.688      0.077461
# 9  {'criterion': 'entropy', 'splitter': 'random'}     0.690      0.087575
#
#    balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  precision  \
# 0           0.648810               0.067285  0.914286    0.044597   0.776238
# 1           0.654048               0.066089  0.921429    0.039301   0.778840
# 2           0.653571               0.075280  0.927143    0.036874   0.778237
# 3           0.643333               0.065933  0.910000    0.048657   0.773494
# 4           0.643810               0.052778  0.924286    0.035557   0.773071
# 5           0.605238               0.085483  0.667143    0.090561   0.784559
# 6           0.641905               0.108071  0.777143    0.111502   0.786719
# 7           0.622143               0.098288  0.754286    0.092662   0.775720
# 8           0.632381               0.077779  0.771429    0.067230   0.781583
# 9           0.637619               0.110753  0.768571    0.078190   0.785718
#
#    dif_precision       fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0       0.072144  0.616667  0.146011           0.825            0.094245
# 1       0.055808  0.613333  0.128508           0.829            0.075218
# 2       0.076822  0.620000  0.134570           0.835            0.077306
# 3       0.056191  0.623333  0.129464           0.824            0.079623
# 4       0.068199  0.636667  0.104997           0.838            0.070235
# 5       0.109373  0.456667  0.175588           0.604            0.089506
# 6       0.081312  0.493333  0.167011           0.692            0.100532
# 7       0.125643  0.510000  0.181522           0.681            0.092771
# 8       0.103378  0.506667  0.108865           0.692            0.063346
# 9       0.099137  0.493333  0.173142           0.686            0.089985
#
#    dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                0.094245       0.044597      0.091480
# 1                0.075218       0.039301      0.069500
# 2                0.077306       0.036874      0.073136
# 3                0.079623       0.048657      0.080092
# 4                0.070235       0.035557      0.064427
# 5                0.089506       0.090561      0.095734
# 6                0.100532       0.111502      0.087451
# 7                0.092771       0.092662      0.105621
# 8                0.063346       0.067230      0.068413
# 9                0.089985       0.078190      0.085396
#
#    disparate_impacto_ratio
# 0                 0.938583
# 1                 0.932600
# 2                 0.926693
# 3                 0.919873
# 4                 0.938372
# 5                 0.967596
# 6                 0.962197
# 7                 0.918400
# 8                 0.976215
# 9                 0.889645
