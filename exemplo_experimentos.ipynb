# %%
import sys
import numpy as np
import pandas as pd

from settings import classifiers_settings_test, classifiers_settings_test_weights
from fairness_experiments import Experiment

# %%
german = pd.read_csv('dataset_test.txt', sep=',', index_col=0)
german
# Out:
#           status  duration (month)  credit amount   savings  employment since  \
# sex
# Male   -1.268991         -1.236478      -0.745131 -1.231393          1.338078
# Female  0.995043          2.248194       0.949817 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.416562 -0.196609          0.510060
# Male   -1.268991          1.750384       1.634247 -0.196609          0.510060
# Male   -1.268991          0.256953       0.566664 -0.196609         -0.317959
# ...          ...               ...            ...       ...               ...
# Female -0.136974         -0.738668      -0.544162 -0.196609          0.510060
# Male   -1.268991          0.754763       0.207612 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.874503 -0.196609          1.338078
# Male   -1.268991          1.999289      -0.505528 -0.196609         -0.317959
# Male    0.995043          1.999289       0.462457  0.838175         -1.973997
#
#         installment rate  residence since       age   credits       job  ...  \
# sex                                                                      ...
# Male            0.918477         1.046987  2.766456  1.027079  0.146949  ...
# Female         -0.870183        -0.765977 -1.191404 -0.704926  0.146949  ...
# Male           -0.870183         0.140505  1.183312 -0.704926 -1.383771  ...
# Male           -0.870183         1.046987  0.831502 -0.704926  0.146949  ...
# Male            0.024147         1.046987  1.535122  1.027079  0.146949  ...
# ...                  ...              ...       ...       ...       ...  ...
# Female          0.024147         1.046987 -0.399832 -0.704926 -1.383771  ...
# Male            0.918477         1.046987  0.391740 -0.704926  1.677670  ...
# Male            0.918477         1.046987  0.215835 -0.704926  0.146949  ...
# Male            0.918477         1.046987 -1.103451 -0.704926  0.146949  ...
# Male            0.024147         1.046987 -0.751642 -0.704926  0.146949  ...
#
#         property_A122  property_A123  property_A124  installment plans_A142  \
# sex
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# ...               ...            ...            ...                     ...
# Female      -0.549621      -0.704987      -0.426653               -0.222076
# Male         1.819435      -0.704987      -0.426653               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
# Male        -0.549621      -0.704987       2.343823               -0.222076
# Male        -0.549621       1.418467      -0.426653               -0.222076
#
#         installment plans_A143  housing_A152  housing_A153  phone_A192  \
# sex
# Male                  0.478018      0.634448     -0.347960    1.214598
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# Male                  0.478018     -1.576173      2.873893   -0.823318
# ...                        ...           ...           ...         ...
# Female                0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018      0.634448     -0.347960    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
# Male                  0.478018     -1.576173      2.873893    1.214598
# Male                  0.478018      0.634448     -0.347960   -0.823318
#
#         foreign worker_A202  class
# sex
# Male              -0.196014      1
# Female            -0.196014      0
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# ...                     ...    ...
# Female            -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      1
# Male              -0.196014      0
# Male              -0.196014      1
#
# [1000 rows x 37 columns]

# %%
X = german.loc[:, german.columns != 'class']
y = np.array(german.loc[:, german.columns == 'class']).ravel()

# %%
X
# Out:
#           status  duration (month)  credit amount   savings  employment since  \
# sex
# Male   -1.268991         -1.236478      -0.745131 -1.231393          1.338078
# Female  0.995043          2.248194       0.949817 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.416562 -0.196609          0.510060
# Male   -1.268991          1.750384       1.634247 -0.196609          0.510060
# Male   -1.268991          0.256953       0.566664 -0.196609         -0.317959
# ...          ...               ...            ...       ...               ...
# Female -0.136974         -0.738668      -0.544162 -0.196609          0.510060
# Male   -1.268991          0.754763       0.207612 -0.196609         -0.317959
# Male   -0.136974         -0.738668      -0.874503 -0.196609          1.338078
# Male   -1.268991          1.999289      -0.505528 -0.196609         -0.317959
# Male    0.995043          1.999289       0.462457  0.838175         -1.973997
#
#         installment rate  residence since       age   credits       job  ...  \
# sex                                                                      ...
# Male            0.918477         1.046987  2.766456  1.027079  0.146949  ...
# Female         -0.870183        -0.765977 -1.191404 -0.704926  0.146949  ...
# Male           -0.870183         0.140505  1.183312 -0.704926 -1.383771  ...
# Male           -0.870183         1.046987  0.831502 -0.704926  0.146949  ...
# Male            0.024147         1.046987  1.535122  1.027079  0.146949  ...
# ...                  ...              ...       ...       ...       ...  ...
# Female          0.024147         1.046987 -0.399832 -0.704926 -1.383771  ...
# Male            0.918477         1.046987  0.391740 -0.704926  1.677670  ...
# Male            0.918477         1.046987  0.215835 -0.704926  0.146949  ...
# Male            0.918477         1.046987 -1.103451 -0.704926  0.146949  ...
# Male            0.024147         1.046987 -0.751642 -0.704926  0.146949  ...
#
#         other debtors_A103  property_A122  property_A123  property_A124  \
# sex
# Male             -0.234206      -0.549621      -0.704987      -0.426653
# Female           -0.234206      -0.549621      -0.704987      -0.426653
# Male             -0.234206      -0.549621      -0.704987      -0.426653
# Male              4.269750       1.819435      -0.704987      -0.426653
# Male             -0.234206      -0.549621      -0.704987       2.343823
# ...                    ...            ...            ...            ...
# Female           -0.234206      -0.549621      -0.704987      -0.426653
# Male             -0.234206       1.819435      -0.704987      -0.426653
# Male             -0.234206      -0.549621       1.418467      -0.426653
# Male             -0.234206      -0.549621      -0.704987       2.343823
# Male             -0.234206      -0.549621       1.418467      -0.426653
#
#         installment plans_A142  installment plans_A143  housing_A152  \
# sex
# Male                 -0.222076                0.478018      0.634448
# Female               -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018     -1.576173
# Male                 -0.222076                0.478018     -1.576173
# ...                        ...                     ...           ...
# Female               -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018      0.634448
# Male                 -0.222076                0.478018     -1.576173
# Male                 -0.222076                0.478018      0.634448
#
#         housing_A153  phone_A192  foreign worker_A202
# sex
# Male       -0.347960    1.214598            -0.196014
# Female     -0.347960   -0.823318            -0.196014
# Male       -0.347960   -0.823318            -0.196014
# Male        2.873893   -0.823318            -0.196014
# Male        2.873893   -0.823318            -0.196014
# ...              ...         ...                  ...
# Female     -0.347960   -0.823318            -0.196014
# Male       -0.347960    1.214598            -0.196014
# Male       -0.347960   -0.823318            -0.196014
# Male        2.873893    1.214598            -0.196014
# Male       -0.347960   -0.823318            -0.196014
#
# [1000 rows x 36 columns]

# %%
exp_teste = Experiment(classifiers_settings_test, dataset_name='German', preprocessing_name='sem pré-processamento', 
                 privileged_group='Male')
exp_teste.execute(X, y)
exp_teste.report
# Out:
# (German - sem pré-processamento) - Classificador Decision Tree (4/4) - Progresso Geral (10/10)
#   dataset          preprocessing       clf_type  \
# 0  German  sem pré-processamento  Random Forest
# 1  German  sem pré-processamento  Random Forest
# 2  German  sem pré-processamento  Random Forest
# 3  German  sem pré-processamento  Random Forest
# 4  German  sem pré-processamento  Random Forest
# 5  German  sem pré-processamento    Naive Bayes
# 6  German  sem pré-processamento  Decision Tree
# 7  German  sem pré-processamento  Decision Tree
# 8  German  sem pré-processamento  Decision Tree
# 9  German  sem pré-processamento  Decision Tree
#
#                                            params  accuracy  dif_accuracy  \
# 0                           {'n_estimators': 120}     0.765      0.056287
# 1                           {'n_estimators': 140}     0.752      0.050184
# 2                           {'n_estimators': 160}     0.756      0.069227
# 3                           {'n_estimators': 180}     0.766      0.049039
# 4                           {'n_estimators': 200}     0.760      0.049434
# 5                                              {}     0.629      0.063052
# 6       {'criterion': 'gini', 'splitter': 'best'}     0.672      0.093722
# 7     {'criterion': 'gini', 'splitter': 'random'}     0.668      0.072667
# 8    {'criterion': 'entropy', 'splitter': 'best'}     0.691      0.054433
# 9  {'criterion': 'entropy', 'splitter': 'random'}     0.668      0.091901
#
#    balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  ...  \
# 0           0.663571               0.076213  0.917143    0.043680  ...
# 1           0.646667               0.061887  0.910000    0.058762  ...
# 2           0.646667               0.071556  0.920000    0.046721  ...
# 3           0.658571               0.069329  0.927143    0.039361  ...
# 4           0.653333               0.051815  0.920000    0.055721  ...
# 5           0.604524               0.060152  0.665714    0.109007  ...
# 6           0.616190               0.097926  0.755714    0.100680  ...
# 7           0.620952               0.076753  0.738571    0.092442  ...
# 8           0.645000               0.066817  0.760000    0.088925  ...
# 9           0.612381               0.083518  0.751429    0.114605  ...
#
#         fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0  0.590000  0.126746           0.819            0.064577
# 1  0.616667  0.132536           0.822            0.083050
# 2  0.626667  0.141842           0.832            0.080008
# 3  0.610000  0.144019           0.832            0.081071
# 4  0.613333  0.101651           0.828            0.077562
# 5  0.456667  0.149139           0.603            0.120458
# 6  0.523333  0.138828           0.686            0.086257
# 7  0.496667  0.125526           0.666            0.094010
# 8  0.470000  0.146364           0.673            0.101370
# 9  0.526667  0.181770           0.684            0.126781
#
#    dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                0.064577       0.043680      0.058313
# 1                0.083050       0.058762      0.081515
# 2                0.080008       0.046721      0.078282
# 3                0.081071       0.039361      0.081384
# 4                0.077562       0.055721      0.070965
# 5                0.120458       0.109007      0.122374
# 6                0.086257       0.100680      0.081629
# 7                0.094010       0.092442      0.090023
# 8                0.101370       0.088925      0.100597
# 9                0.126781       0.114605      0.134446
#
#    disparate_impacto_ratio  theil_index  coef_variation
# 0                 0.929623     0.106731        0.592016
# 1                 0.913087     0.113326        0.605174
# 2                 0.919460     0.105902        0.590549
# 3                 0.923950     0.099771        0.578433
# 4                 0.920485     0.105499        0.590232
# 5                 0.943045     0.330066        0.954189
# 6                 0.926674     0.234398        0.818458
# 7                 0.946442     0.248357        0.839403
# 8                 0.928643     0.228206        0.803559
# 9                 0.880063     0.239116        0.826654
#
# [10 rows x 22 columns]

# %%
exp_teste.export_report(relative_path='resultados_teste/')

# %%
# faz o teste com pesos
weights = [2]*len(y)

# %%
exp_teste = Experiment(classifiers_settings_test_weights, dataset_name='German', preprocessing_name='sem pré-processamento', 
                 privileged_group='Male')
exp_teste.execute(X, y, weights)
exp_teste.report
# Out:
# (German - sem pré-processamento) - Classificador Decision Tree (4/4) - Progresso Geral (10/10)
#   dataset          preprocessing       clf_type  \
# 0  German  sem pré-processamento  Random Forest
# 1  German  sem pré-processamento  Random Forest
# 2  German  sem pré-processamento  Random Forest
# 3  German  sem pré-processamento  Random Forest
# 4  German  sem pré-processamento  Random Forest
# 5  German  sem pré-processamento    Naive Bayes
# 6  German  sem pré-processamento  Decision Tree
# 7  German  sem pré-processamento  Decision Tree
# 8  German  sem pré-processamento  Decision Tree
# 9  German  sem pré-processamento  Decision Tree
#
#                                            params  accuracy  dif_accuracy  \
# 0                           {'n_estimators': 120}     0.759      0.067367
# 1                           {'n_estimators': 140}     0.764      0.055540
# 2                           {'n_estimators': 160}     0.760      0.046065
# 3                           {'n_estimators': 180}     0.772      0.044441
# 4                           {'n_estimators': 200}     0.764      0.054130
# 5                                              {}     0.629      0.063052
# 6       {'criterion': 'gini', 'splitter': 'best'}     0.677      0.067574
# 7     {'criterion': 'gini', 'splitter': 'random'}     0.666      0.071864
# 8    {'criterion': 'entropy', 'splitter': 'best'}     0.692      0.065818
# 9  {'criterion': 'entropy', 'splitter': 'random'}     0.680      0.078485
#
#    balanced_accuracy  dif_balanced_accuracy    recall  dif_recall  ...  \
# 0           0.655476               0.066543  0.914286    0.059082  ...
# 1           0.665714               0.062713  0.911429    0.046082  ...
# 2           0.653333               0.061967  0.920000    0.023361  ...
# 3           0.667619               0.074534  0.928571    0.041361  ...
# 4           0.659048               0.080421  0.921429    0.043483  ...
# 5           0.604524               0.060152  0.665714    0.109007  ...
# 6           0.619762               0.074183  0.762857    0.077122  ...
# 7           0.606190               0.057319  0.755714    0.091605  ...
# 8           0.641905               0.068147  0.767143    0.081204  ...
# 9           0.612381               0.077143  0.781429    0.122844  ...
#
#         fpr   dif_fpr  selection_rate  dif_selection_rate  \
# 0  0.603333  0.143756           0.821            0.091426
# 1  0.580000  0.102129           0.812            0.054708
# 2  0.613333  0.120574           0.828            0.058421
# 3  0.593333  0.161890           0.828            0.084722
# 4  0.603333  0.159282           0.826            0.071203
# 5  0.456667  0.149139           0.603            0.120458
# 6  0.523333  0.110383           0.691            0.083952
# 7  0.543333  0.131053           0.692            0.089983
# 8  0.483333  0.144402           0.682            0.080568
# 9  0.556667  0.133923           0.714            0.120269
#
#    dif_statistical_parity  dif_equal_opp  dif_avg_odds  \
# 0                0.091426       0.059082      0.091337
# 1                0.054708       0.046082      0.047368
# 2                0.058421       0.023361      0.065128
# 3                0.084722       0.041361      0.095265
# 4                0.071203       0.043483      0.084383
# 5                0.120458       0.109007      0.122374
# 6                0.083952       0.077122      0.076054
# 7                0.089983       0.091605      0.092152
# 8                0.080568       0.081204      0.083803
# 9                0.120269       0.122844      0.110991
#
#    disparate_impacto_ratio  theil_index  coef_variation
# 0                 0.894881     0.109576        0.597452
# 1                 0.935739     0.110710        0.598695
# 2                 0.936941     0.105744        0.589911
# 3                 0.910703     0.098218        0.573855
# 4                 0.946003     0.104126        0.586277
# 5                 0.943045     0.330066        0.954189
# 6                 0.915054     0.228613        0.808080
# 7                 0.931597     0.236354        0.822221
# 8                 0.949677     0.223550        0.796375
# 9                 0.846284     0.214493        0.785812
#
# [10 rows x 22 columns]
